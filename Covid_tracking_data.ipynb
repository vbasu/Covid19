# %%
import pandas as pd
df = pd.read_csv('Data/daily.csv')
df.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200430    AK     355.0   18764.0      NaN                   19.0
# 1  20200430    AL    7019.0   80177.0      NaN                    NaN
# 2  20200430    AR    3255.0   45124.0      NaN                   95.0
# 3  20200430    AS       0.0       3.0     17.0                    NaN
# 4  20200430    AZ    7648.0   64138.0      NaN                  755.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                     NaN             NaN              NaN
# 1                   978.0             NaN            335.0
# 2                   402.0             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                  1169.0           311.0              NaN
#
#    onVentilatorCurrently  ...  hospitalized    total totalTestResults  \
# 0                    NaN  ...           NaN  19119.0          19119.0
# ...

# %%
ny_data = df.loc[df['state'] == 'NY']
ny_data.head()
# Out:
#          date state  positive  negative  pending  hospitalizedCurrently  \
# 37   20200430    NY  304372.0  596264.0      NaN                11598.0
# 93   20200429    NY  299691.0  572790.0      NaN                12159.0
# 149  20200428    NY  295106.0  549888.0      NaN                12645.0
# 205  20200427    NY  291996.0  534099.0      NaN                12819.0
# 261  20200426    NY  288045.0  517305.0      NaN                12839.0
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 37                  66369.0             NaN              NaN
# 93                  65397.0             NaN              NaN
# 149                 64318.0             NaN              NaN
# 205                 63570.0             NaN              NaN
# 261                 62526.0          5016.0              NaN
#
#      onVentilatorCurrently  ...  hospitalized     total totalTestResults  \
# 37                     NaN  ...       66369.0  900636.0         900636.0
# ...

# %%
va_data = df.loc[df['state'] == 'VA']
va_data.head()
# Out:
#          date state  positive  negative  pending  hospitalizedCurrently  \
# 49   20200430    VA   15846.0   75663.0    583.0                 1550.0
# 105  20200429    VA   14961.0   70979.0    620.0                 1566.0
# 161  20200428    VA   13794.0   68959.0    560.0                 1508.0
# 217  20200427    VA   13535.0   67144.0    542.0                 1455.0
# 273  20200426    VA   12488.0   63630.0    539.0                 1436.0
#
#      hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 49                   3654.0           372.0              NaN
# 105                  3608.0           387.0              NaN
# 161                  3422.0           376.0              NaN
# 217                  3298.0           389.0              NaN
# 273                  2014.0           387.0              NaN
#
#      onVentilatorCurrently  ...  hospitalized    total totalTestResults  \
# 49                   208.0  ...        3654.0  92092.0          91509.0
# ...

# %%
df = pd.read_csv('Data/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')

# %%
df.head()
# Out:
#      UID iso2 iso3  code3  FIPS Admin2            Province_State  \
# 0   16.0   AS  ASM     16  60.0    NaN            American Samoa
# 1  316.0   GU  GUM    316  66.0    NaN                      Guam
# 2  580.0   MP  MNP    580  69.0    NaN  Northern Mariana Islands
# 3  630.0   PR  PRI    630  72.0    NaN               Puerto Rico
# 4  850.0   VI  VIR    850  78.0    NaN            Virgin Islands
#
#   Country_Region      Lat     Long_  ... 4/20/20  4/21/20  4/22/20  4/23/20  \
# 0             US -14.2710 -170.1320  ...       0        0        0        0
# 1             US  13.4443  144.7937  ...     136      136      136      139
# 2             US  15.0979  145.6739  ...      14       14       14       14
# 3             US  18.2208  -66.5901  ...    1252     1298     1252     1416
# 4             US  18.3358  -64.8963  ...      53       53       54       54
#
#    4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 0        0        0        0        0        0        0
# ...

# %%
df.columns
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_',
#        ...
#        '4/20/20', '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20',
#        '4/26/20', '4/27/20', '4/28/20', '4/29/20'],
#       dtype='object', length=110)

# %%
list(df.columns)
# Out:
# ['UID',
#  'iso2',
#  'iso3',
#  'code3',
#  'FIPS',
#  'Admin2',
#  'Province_State',
#  'Country_Region',
#  'Lat',
#  'Long_',
#  'Combined_Key',
#  '1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
# ...

# %%
df.tail()
# Out:
#              UID iso2 iso3  code3     FIPS          Admin2 Province_State  \
# 3257  84070017.0   US  USA    840      NaN  Southeast Utah           Utah
# 3258  84070018.0   US  USA    840      NaN  Southwest Utah           Utah
# 3259  84070019.0   US  USA    840      NaN       TriCounty           Utah
# 3260  84070020.0   US  USA    840      NaN    Weber-Morgan           Utah
# 3261         NaN   US  USA    840  90049.0       Southwest           Utah
#
#      Country_Region        Lat       Long_  ... 4/20/20  4/21/20  4/22/20  \
# 3257             US  38.996171 -110.701396  ...       7        7        7
# 3258             US  37.854472 -111.441876  ...      70       70       70
# 3259             US  40.124915 -109.517442  ...      10       10        9
# 3260             US  41.271160 -111.914512  ...     124      126      130
# 3261             US        NaN         NaN  ...       0        0        0
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# ...

# %%
va_data = df.loc[df['Province_State'] == 'Virginia']
va_data
# Out:
#              UID iso2 iso3  code3     FIPS        Admin2 Province_State  \
# 2825  84051001.0   US  USA    840  51001.0      Accomack       Virginia
# 2826  84051003.0   US  USA    840  51003.0     Albemarle       Virginia
# 2827  84051005.0   US  USA    840  51005.0     Alleghany       Virginia
# 2828  84051007.0   US  USA    840  51007.0        Amelia       Virginia
# 2829  84051009.0   US  USA    840  51009.0       Amherst       Virginia
# ...          ...  ...  ...    ...      ...           ...            ...
# 2955  84051820.0   US  USA    840  51820.0    Waynesboro       Virginia
# 2956  84051830.0   US  USA    840  51830.0  Williamsburg       Virginia
# 2957  84051840.0   US  USA    840  51840.0    Winchester       Virginia
# 3195  84080051.0   US  USA    840  80051.0     Out of VA       Virginia
# 3247  84090051.0   US  USA    840  90051.0    Unassigned       Virginia
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# ...

# %%
arlington_data = va_data.loc[va_data['Admin2'] == 'Arlington']
arlington_data
# Out:
#              UID iso2 iso3  code3     FIPS     Admin2 Province_State  \
# 2831  84051013.0   US  USA    840  51013.0  Arlington       Virginia
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# 2831             US  38.876767 -77.101399  ...     593      625      663
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 2831      686      722      764      790      836      865      912
#
# [1 rows x 110 columns]

# %%
fairfax_data = va_data.loc[va_data['Admin2'] == 'Fairfax']
fairfax_data
# Out:
#              UID iso2 iso3  code3     FIPS   Admin2 Province_State  \
# 2853  84051059.0   US  USA    840  51059.0  Fairfax       Virginia
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# 2853             US  38.836776 -77.275658  ...    1925     2077     2256
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 2853     2362     2534     2745     2889     3002     3278     3448
#
# [1 rows x 110 columns]

# %%
ny_data = df.loc[df['Province_State'] == 'New York']
ny_data
# Out:
#              UID iso2 iso3  code3     FIPS       Admin2 Province_State  \
# 1833  84036001.0   US  USA    840  36001.0       Albany       New York
# 1834  84036003.0   US  USA    840  36003.0     Allegany       New York
# 1835  84036005.0   US  USA    840  36005.0        Bronx       New York
# 1836  84036007.0   US  USA    840  36007.0       Broome       New York
# 1837  84036009.0   US  USA    840  36009.0  Cattaraugus       New York
# ...          ...  ...  ...    ...      ...          ...            ...
# 1892  84036119.0   US  USA    840  36119.0  Westchester       New York
# 1893  84036121.0   US  USA    840  36121.0      Wyoming       New York
# 1894  84036123.0   US  USA    840  36123.0        Yates       New York
# 3181  84080036.0   US  USA    840  80036.0    Out of NY       New York
# 3233  84090036.0   US  USA    840  90036.0   Unassigned       New York
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# ...

# %%
cville_data = va_data.loc[va_data['Admin2'] == 'Charlottesville']
cville_data
# Out:
#              UID iso2 iso3  code3     FIPS           Admin2 Province_State  \
# 2923  84051540.0   US  USA    840  51540.0  Charlottesville       Virginia
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# 2923             US  38.035279 -78.485696  ...      41       41       44
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 2923       44       45       48       49       50       51       52
#
# [1 rows x 110 columns]

# %%
albany_data = ny_data.loc[df['Admin2'] == 'Albany']
albany_data
# Out:
#              UID iso2 iso3  code3     FIPS  Admin2 Province_State  \
# 1833  84036001.0   US  USA    840  36001.0  Albany       New York
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# 1833             US  42.600603 -73.977239  ...     687      704      737
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 1833      758      805      899      948      979     1009     1067
#
# [1 rows x 110 columns]

# %%
albany_data.columns
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_',
#        ...
#        '4/20/20', '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20',
#        '4/26/20', '4/27/20', '4/28/20', '4/29/20'],
#       dtype='object', length=110)
